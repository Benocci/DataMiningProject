# %% [markdown]
# # Utility file to show main information about the dataset

# %%
import warnings
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

from collections import defaultdict
from scipy.stats import pearsonr

import os

#reading the dataset
cyclists = pd.read_csv('./dataset/cyclists.csv')
races = pd.read_csv('./dataset/races.csv')

# %% [markdown]
# ## Cyclist dataset

# %%
cyclists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6134 entries, 0 to 6133
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _url         6134 non-null   object
#  1   name         6134 non-null   object
#  2   birth_year   6121 non-null   float64
#  3   weight       3078 non-null   float64
#  4   height       3143 non-null   float64
#  5   nationality  6133 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 287.7+ KB

# %%
cyclists.head()
# Out:
#                    _url                  name  birth_year  weight  height  \
# 0           bruno-surra          Bruno  Surra      1964.0     NaN     NaN
# 1            gerard-rue           Gérard  Rué      1965.0    74.0   182.0
# 2              jan-maas             Jan  Maas      1996.0    69.0   189.0
# 3  nathan-van-hooydonck  Nathan Van Hooydonck      1995.0    78.0   192.0
# 4      jose-felix-parra     José Félix  Parra      1997.0    55.0   171.0
#
#    nationality
# 0        Italy
# 1       France
# 2  Netherlands
# 3      Belgium
# 4        Spain

# %% [markdown]
# ## Races dataset

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589865 entries, 0 to 589864
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   _url                 589865 non-null  object
#  1   name                 589865 non-null  object
#  2   points               589388 non-null  float64
#  3   uci_points           251086 non-null  float64
#  4   length               589865 non-null  float64
#  5   climb_total          442820 non-null  float64
#  6   profile              441671 non-null  float64
#  7   startlist_quality    589865 non-null  int64
#  8   average_temperature  29933 non-null   float64
#  9   date                 589865 non-null  object
#  10  position             589865 non-null  int64
#  11  cyclist              589865 non-null  object
#  12  cyclist_age          589752 non-null  float64
#  13  is_tarmac            589865 non-null  bool
#  14  is_cobbled           589865 non-null  bool
#  15  is_gravel            589865 non-null  bool
#  16  cyclist_team         430704 non-null  object
#  17  delta                589865 non-null  float64
# dtypes: bool(3), float64(8), int64(2), object(5)
# memory usage: 69.2+ MB

# %%
races.head()
# Out:
#                           _url            name  points  uci_points    length  \
# 0  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 1  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 2  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 3  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
# 4  tour-de-france/1978/stage-6  Tour de France   100.0         NaN  162000.0
#
#    climb_total  profile  startlist_quality  average_temperature  \
# 0       1101.0      1.0               1241                  NaN
# 1       1101.0      1.0               1241                  NaN
# 2       1101.0      1.0               1241                  NaN
# 3       1101.0      1.0               1241                  NaN
# 4       1101.0      1.0               1241                  NaN
#
#                   date  position           cyclist  cyclist_age  is_tarmac  \
# 0  1978-07-05 04:02:24         0        sean-kelly         22.0       True
# 1  1978-07-05 04:02:24         1  gerrie-knetemann         27.0       True
# 2  1978-07-05 04:02:24         2    rene-bittinger         24.0       True
# 3  1978-07-05 04:02:24         3    joseph-bruyere         30.0       True
# 4  1978-07-05 04:02:24         4  sven-ake-nilsson         27.0       True
#
#    is_cobbled  is_gravel                          cyclist_team  delta
# 0       False      False  vini-ricordi-pinarello-sidermec-1986    0.0
# 1       False      False                           norway-1987    0.0
# 2       False      False                                   NaN    0.0
# 3       False      False              navigare-blue-storm-1993    0.0
# 4       False      False                            spain-1991    0.0

# %%
# numero entry con diversi terreni
race_cobbled = races['is_cobbled'].sum()
race_tarmac = races['is_tarmac'].sum()
race_gravel = races['is_gravel'].sum()
print(f"Cobble:{race_cobbled} Tarmac:{race_tarmac} Gravel:{race_gravel}")
# Out:
# Cobble:0 Tarmac:536042 Gravel:0

# %%
races.tail()
# Out:
#                               _url           name  points  uci_points  length  \
# 589860  giro-d-italia/2010/stage-1  Giro d'Italia    80.0        16.0  8400.0
# 589861  giro-d-italia/2010/stage-1  Giro d'Italia    80.0        16.0  8400.0
# 589862  giro-d-italia/2010/stage-1  Giro d'Italia    80.0        16.0  8400.0
# 589863  giro-d-italia/2010/stage-1  Giro d'Italia    80.0        16.0  8400.0
# 589864  giro-d-italia/2010/stage-1  Giro d'Italia    80.0        16.0  8400.0
#
#         climb_total  profile  startlist_quality  average_temperature  \
# 589860         60.0      1.0                878                  NaN
# 589861         60.0      1.0                878                  NaN
# 589862         60.0      1.0                878                  NaN
# 589863         60.0      1.0                878                  NaN
# 589864         60.0      1.0                878                  NaN
#
#                        date  position             cyclist  cyclist_age  \
# 589860  2010-05-08 00:11:38       192       anders-lund-1         25.0
# 589861  2010-05-08 00:11:40       193  andrea-masciarelli         28.0
# 589862  2010-05-08 00:11:41       194         marco-corti         24.0
# 589863  2010-05-08 00:11:48       195       robbie-mcewen         38.0
# 589864  2010-05-08 00:11:49       196     martin-pedersen         27.0
#
#         is_tarmac  is_cobbled  is_gravel                         cyclist_team  \
# 589860       True       False      False                     watney-avia-1972
# 589861       True       False      False                                  NaN
# 589862       True       False      False                      kazakhstan-2001
# 589863       True       False      False  radio-popular-paredes-boavista-2023
# 589864       True       False      False                      kazakhstan-2001
#
#         delta
# 589860   80.0
# 589861   82.0
# 589862   83.0
# 589863   90.0
# 589864   91.0

# %%
# show the entries with uci_points > 500
races[races['date'].str.contains('1978')]
# Out:
#                                 _url            name  points  uci_points  \
# 0        tour-de-france/1978/stage-6  Tour de France   100.0         NaN
# 1        tour-de-france/1978/stage-6  Tour de France   100.0         NaN
# 2        tour-de-france/1978/stage-6  Tour de France   100.0         NaN
# 3        tour-de-france/1978/stage-6  Tour de France   100.0         NaN
# 4        tour-de-france/1978/stage-6  Tour de France   100.0         NaN
# ...                              ...             ...     ...         ...
# 580807  tour-de-suisse/1978/stage-9a  Tour de Suisse    50.0         NaN
# 580808  tour-de-suisse/1978/stage-9a  Tour de Suisse    50.0         NaN
# 580809  tour-de-suisse/1978/stage-9a  Tour de Suisse    50.0         NaN
# 580810  tour-de-suisse/1978/stage-9a  Tour de Suisse    50.0         NaN
# 580811  tour-de-suisse/1978/stage-9a  Tour de Suisse    50.0         NaN
#
#           length  climb_total  profile  startlist_quality  \
# 0       162000.0       1101.0      1.0               1241
# 1       162000.0       1101.0      1.0               1241
# 2       162000.0       1101.0      1.0               1241
# 3       162000.0       1101.0      1.0               1241
# 4       162000.0       1101.0      1.0               1241
# ...          ...          ...      ...                ...
# 580807   97500.0          NaN      NaN                691
# 580808   97500.0          NaN      NaN                691
# 580809   97500.0          NaN      NaN                691
# 580810   97500.0          NaN      NaN                691
# 580811   97500.0          NaN      NaN                691
#
#         average_temperature                 date  position  \
# 0                       NaN  1978-07-05 04:02:24         0
# 1                       NaN  1978-07-05 04:02:24         1
# 2                       NaN  1978-07-05 04:02:24         2
# 3                       NaN  1978-07-05 04:02:24         3
# 4                       NaN  1978-07-05 04:02:24         4
# ...                     ...                  ...       ...
# 580807                  NaN  1978-06-23 02:18:22         1
# 580808                  NaN  1978-06-23 02:18:22         2
# 580809                  NaN  1978-06-23 02:18:22         3
# 580810                  NaN  1978-06-23 02:18:22         4
# 580811                  NaN  1978-06-23 02:18:22         5
#
#                        cyclist  cyclist_age  is_tarmac  is_cobbled  is_gravel  \
# 0                   sean-kelly         22.0       True       False      False
# 1             gerrie-knetemann         27.0       True       False      False
# 2               rene-bittinger         24.0       True       False      False
# 3               joseph-bruyere         30.0       True       False      False
# 4             sven-ake-nilsson         27.0       True       False      False
# ...                        ...          ...        ...         ...        ...
# 580807          piero-spinelli         30.0       True       False      False
# 580808  gustaaf-van-roosbroeck         30.0       True       False      False
# 580809           jean-chassang         27.0       True       False      False
# 580810            clyde-sefton         27.0       True       False      False
# 580811            marc-demeyer         28.0       True       False      False
#
#                                 cyclist_team  delta
# 0       vini-ricordi-pinarello-sidermec-1986    0.0
# 1                                norway-1987    0.0
# 2                                        NaN    0.0
# 3                   navigare-blue-storm-1993    0.0
# 4                                 spain-1991    0.0
# ...                                      ...    ...
# 580807                                   NaN    0.0
# 580808      team-saxo-bank-tinkoff-bank-2012    0.0
# 580809                                   NaN    0.0
# 580810                                   NaN    0.0
# 580811  vini-ricordi-pinarello-sidermec-1986    0.0
#
# [2618 rows x 18 columns]

# %%
# stampa i dati delle gare che hanno "result" nella _url
races[races['_url'].str.contains('result')].head()
# Out:
#                                   _url  \
# 1269  ronde-van-vlaanderen/1980/result
# 1270  ronde-van-vlaanderen/1980/result
# 1271  ronde-van-vlaanderen/1980/result
# 1272  ronde-van-vlaanderen/1980/result
# 1273  ronde-van-vlaanderen/1980/result
#
#                                           name  points  uci_points    length  \
# 1269  Ronde van Vlaanderen / Tour des Flandres   275.0         NaN  265000.0
# 1270  Ronde van Vlaanderen / Tour des Flandres   275.0         NaN  265000.0
# 1271  Ronde van Vlaanderen / Tour des Flandres   275.0         NaN  265000.0
# 1272  Ronde van Vlaanderen / Tour des Flandres   275.0         NaN  265000.0
# 1273  Ronde van Vlaanderen / Tour des Flandres   275.0         NaN  265000.0
#
#       climb_total  profile  startlist_quality  average_temperature  \
# 1269          NaN      NaN                602                  NaN
# 1270          NaN      NaN                602                  NaN
# 1271          NaN      NaN                602                  NaN
# 1272          NaN      NaN                602                  NaN
# 1273          NaN      NaN                602                  NaN
#
#                      date  position             cyclist  cyclist_age  \
# 1269  1980-03-30 06:36:45         0   michel-pollentier         29.0
# 1270  1980-03-30 06:36:45         1     francesco-moser         29.0
# 1271  1980-03-30 06:36:45         2            jan-raas         28.0
# 1272  1980-03-30 06:37:05         3  roger-de-vlaeminck         33.0
# 1273  1980-03-30 06:37:05         4        marc-demeyer         30.0
#
#       is_tarmac  is_cobbled  is_gravel                     cyclist_team  delta
# 1269      False       False      False                   australia-1983    0.0
# 1270      False       False      False                       japan-2008    0.0
# 1271      False       False      False  liberty-seguros-wurth-team-2005    0.0
# 1272      False       False      False                    liquigas-2007   20.0
# 1273      False       False      False             ag2r-prevoyance-2001   20.0

# %%
races[races['climb_total'] > 6500]
# Out:
#                                   _url                        name  points  \
# 56822      giro-d-italia/2011/stage-15               Giro d'Italia    80.0
# 56823      giro-d-italia/2011/stage-15               Giro d'Italia    80.0
# 56824      giro-d-italia/2011/stage-15               Giro d'Italia    80.0
# 56825      giro-d-italia/2011/stage-15               Giro d'Italia    80.0
# 56826      giro-d-italia/2011/stage-15               Giro d'Italia    80.0
# ...                                ...                         ...     ...
# 337313  volta-a-catalunya/1995/stage-4  Volta Ciclista a Catalunya    50.0
# 337314  volta-a-catalunya/1995/stage-4  Volta Ciclista a Catalunya    50.0
# 337315  volta-a-catalunya/1995/stage-4  Volta Ciclista a Catalunya    50.0
# 337316  volta-a-catalunya/1995/stage-4  Volta Ciclista a Catalunya    50.0
# 337317  volta-a-catalunya/1995/stage-4  Volta Ciclista a Catalunya    50.0
#
#         uci_points    length  climb_total  profile  startlist_quality  \
# 56822         16.0  229000.0       6939.0      5.0                891
# 56823         16.0  229000.0       6939.0      5.0                891
# 56824         16.0  229000.0       6939.0      5.0                891
# 56825         16.0  229000.0       6939.0      5.0                891
# 56826         16.0  229000.0       6939.0      5.0                891
# ...            ...       ...          ...      ...                ...
# 337313         NaN  226800.0       6687.0      NaN                737
# 337314         NaN  226800.0       6687.0      NaN                737
# 337315         NaN  226800.0       6687.0      NaN                737
# 337316         NaN  226800.0       6687.0      NaN                737
# 337317         NaN  226800.0       6687.0      NaN                737
#
#         average_temperature                 date  position  \
# 56822                   NaN  2011-05-22 07:27:14         0
# 56823                   NaN  2011-05-22 07:28:55         1
# 56824                   NaN  2011-05-22 07:29:05         2
# 56825                   NaN  2011-05-22 07:29:11         3
# 56826                   NaN  2011-05-22 07:29:42         4
# ...                     ...                  ...       ...
# 337313                  NaN  1995-06-19 06:31:10        15
# 337314                  NaN  1995-06-19 06:31:28        16
# 337315                  NaN  1995-06-19 06:32:00        17
# 337316                  NaN  1995-06-19 06:32:15        18
# 337317                  NaN  1995-06-19 06:32:34        19
#
#                        cyclist  cyclist_age  is_tarmac  is_cobbled  is_gravel  \
# 56822              mikel-nieve         27.0       True       False      False
# 56823         stefano-garzelli         38.0       True       False      False
# 56824         alberto-contador         29.0       True       False      False
# 56825         michele-scarponi         32.0       True       False      False
# 56826              john-gadret         32.0       True       False      False
# ...                        ...          ...        ...         ...        ...
# 337313          massimo-donati         28.0       True       False      False
# 337314           yvon-ledanois         26.0       True       False      False
# 337315  jose-manuel-garcia-114         27.0       True       False      False
# 337316            pascal-herve         31.0       True       False      False
# 337317        philippe-gaumont         22.0       True       False      False
#
#                        cyclist_team  delta
# 56822                    japan-2008    0.0
# 56823             south-africa-2022  101.0
# 56824              new-zealand-1991  111.0
# 56825         lotto-super-club-1991  117.0
# 56826           team-volksbank-2008  148.0
# ...                             ...    ...
# 337313  o.n.c.e.-deutsche-bank-2000  180.0
# 337314                          NaN  198.0
# 337315                          NaN  230.0
# 337316                          NaN  245.0
# 337317     navigare-blue-storm-1993  264.0
#
# [420 rows x 18 columns]
